# %% [markdown]
# # Group 0 - Diane Woodbridge, Precipitation and Crimes in San Francsico

# %%
from datetime import datetime

import numpy as np

from pyspark.sql import SparkSession
from pyspark.sql.types import *
from pyspark.sql.functions import *
from pyspark.ml.feature import StringIndexer
from pyspark.ml.feature import OneHotEncoder
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.tuning import CrossValidator
from pyspark.ml.tuning import ParamGridBuilder
from pyspark.ml.regression import RandomForestRegressor
from pyspark.ml.evaluation import RegressionEvaluator

# %%
spark = SparkSession.builder.getOrCreate()

# %% [markdown]
# ### Load data from MongoDB and Create features/label

# %%
database = 'msds697'
collection = 'sf_record'
user_name = 'admin'
password = 'msds697'
address = 'msds697.qgylt.mongodb.net'
connection_string = f"mongodb+srv://{user_name}:{password}@{address}/{database}.{collection}"

# %%
df = spark.read.format("mongo").option("uri",connection_string).load()

# %%
df.show()
# Out:
# +---------------------------+--------+--------------------+---------------------+----------+--------------------+---------------+--------------------+---------------------+------------------+-----------------------+------------------------+--------------------+--------------------+--------------------+--------------------+-----------+--------------------+--------------------+---------------+--------------------+--------------------+--------------------+-----------+---------------+--------------+----------------+--------------------+--------------+-------------------+-------+
# |:@computed_region_ajp5_b2md|     _id|              agency|analysis_neighborhood|cad_number|call_last_updated_at|call_type_final|call_type_final_desc|call_type_final_notes|call_type_original|call_type_original_desc|call_type_original_notes|      close_datetime|          data_as_of|      data_loaded_at|   dispatch_datetime|disposition|    enroute_datetime|      entry_datetime|intersection_id|   intersection_name|  intersection_point|    onscene_datetime|onview_flag|police_district|priority_final|priority_orginal|   received_datetime|sensitive_call|supervisor_district|weather|
# +---------------------------+--------+--------------------+---------------------+----------+--------------------+---------------+--------------------+---------------------+------------------+-----------------------+------------------------+--------------------+--------------------+--------------------+--------------------+-----------+--------------------+--------------------+---------------+--------------------+--------------------+--------------------+-----------+---------------+--------------+----------------+--------------------+--------------+-------------------+-------+
# |                       null|20344060|              Police|                 null| 230160007|2023-01-16T00:45:...|            801|     SUICIDE ATTEMPT|                 null|               801|        SUICIDE ATTEMPT|                    null|2023-01-16T00:45:...|2023-01-17T15:53:...|2023-01-17T15:56:...|2023-01-16T00:08:...|        UTL|2023-01-16T00:08:...|2023-01-16T00:07:...|           null|                null|                null|2023-01-16T00:11:...|          N|           null|             A|               A|2023-01-16T00:06:...|          True|               null|     []|
# |                       null|20346023|              Police|                 null| 230160431|2023-01-16T06:59:...|            903|        PASSING CALL|                 null|               903|           PASSING CALL|                    null|2023-01-16T06:49:...|2023-01-17T15:53:...|2023-01-17T15:56:...|2023-01-16T06:44:...|       null|2023-01-16T06:44:...|2023-01-16T06:44:...|           null|                null|                null|2023-01-16T06:44:...|          Y|           null|             C|               C|2023-01-16T06:44:...|          True|               null|     []|
# |                       null|20349425|              Police|                 null| 230160681|2023-01-16T12:40:...|            903|        PASSING CALL|                 null|               903|           PASSING CALL|                    null|2023-01-16T12:40:...|2023-01-17T15:53:...|2023-01-17T15:56:...|2023-01-16T09:05:...|       null|2023-01-16T09:05:...|2023-01-16T09:05:...|           null|                null|                null|2023-01-16T09:05:...|          Y|           null|             C|               C|2023-01-16T09:05:...|          True|               null|     []|
# |                       null|20357745|              Police|                 null| 230162717|2023-01-17T02:06:...|          240DV|ASSAULT / BATTERY DV|                 null|             240DV|   ASSAULT / BATTERY DV|                    null|2023-01-17T02:06:...|2023-01-17T15:53:...|2023-01-17T15:56:...|2023-01-16T20:45:...|        REP|2023-01-16T20:45:...|2023-01-16T20:45:...|           null|                null|                null|2023-01-16T21:05:...|          N|           null|             A|               A|2023-01-16T20:44:...|          True|               null|     []|
# |                       null|20351245|              Police|                 null| 230161694|2023-01-16T14:55:...|           100P|         PANIC ALARM|                 null|              100S|           SILENT ALARM|                    null|2023-01-16T14:55:...|2023-01-17T15:53:...|2023-01-17T15:56:...|2023-01-16T14:37:...|        PAS|2023-01-16T14:37:...|2023-01-16T14:36:...|           null|                null|                null|2023-01-16T14:41:...|          N|           null|             A|               A|2023-01-16T14:34:...|          True|               null|     []|
# |                         36|20349599|              Police|           Tenderloin| 230161213|2023-01-16T12:54:...|            601|          TRESPASSER|                  RTL|               601|             TRESPASSER|                     RTL|2023-01-16T12:54:...|2023-01-17T15:53:...|2023-01-17T15:56:...|2023-01-16T12:50:...|        HAN|2023-01-16T12:50:...|2023-01-16T12:06:...|       25176000|   POLK ST \ EDDY ST|{'type': 'Point',...|2023-01-16T12:50:...|          N|       NORTHERN|             B|               B|2023-01-16T12:05:...|         False|                  6|     []|
# |                          4|20347479|              Police|          Mission Bay| 230160639|2023-01-16T09:51:...|            910|    WELL BEING CHECK|                 null|               910|       WELL BEING CHECK|                    null|2023-01-16T09:51:...|2023-01-17T15:53:...|2023-01-17T15:56:...|2023-01-16T09:01:...|        NOM|2023-01-16T09:01:...|2023-01-16T08:49:...|       34188000|  KING ST \ BERRY ST|{'type': 'Point',...|2023-01-16T09:27:...|          N|       SOUTHERN|             B|               B|2023-01-16T08:44:...|         False|                  6|     []|
# |                       null|20350099|              Police|                 null| 230161394|2023-01-16T13:31:...|           100A|       AUDIBLE ALARM|                 null|              100A|          AUDIBLE ALARM|                    null|2023-01-16T13:31:...|2023-01-17T15:53:...|2023-01-17T15:56:...|2023-01-16T13:21:...|        PAS|2023-01-16T13:21:...|2023-01-16T13:08:...|           null|                null|                null|2023-01-16T13:30:...|          N|           null|             B|               B|2023-01-16T13:06:...|          True|               null|     []|
# |                       null|20356328|              Police|                 null| 230162913|2023-01-16T22:14:...|            585|        TRAFFIC STOP|                 null|               585|           TRAFFIC STOP|                    null|2023-01-16T22:13:...|2023-01-17T15:53:...|2023-01-17T15:56:...|2023-01-16T22:09:...|        ADV|2023-01-16T22:09:...|2023-01-16T22:09:...|           null|                null|                null|2023-01-16T22:09:...|          Y|           null|             B|               B|2023-01-16T22:09:...|          True|               null|     []|
# |                         36|20351864|              Police|           Tenderloin| 230161916|2023-01-16T15:47:...|            917|   SUSPICIOUS PERSON|                 null|               917|      SUSPICIOUS PERSON|                    null|2023-01-16T15:47:...|2023-01-17T15:53:...|2023-01-17T15:56:...|2023-01-16T15:37:...|        HAN|2023-01-16T15:37:...|2023-01-16T15:37:...|       25144000|  ELLIS ST \ HYDE ST|{'type': 'Point',...|2023-01-16T15:37:...|          Y|     TENDERLOIN|             C|               C|2023-01-16T15:37:...|         False|                  6|     []|
# |                         34|20353545|Municipal Transpo...|      South of Market| 230161878|2023-01-16T17:52:...|            587| TRAF VIOLATION CITE|                  NPA|               587|    TRAF VIOLATION CITE|                     NPA|2023-01-16T17:52:...|2023-01-17T15:53:...|2023-01-17T15:56:...|2023-01-16T16:40:...|        CIT|2023-01-16T16:40:...|2023-01-16T15:26:...|       23943000|CLEMENTINA ST \ 0...|{'type': 'Point',...|2023-01-16T16:53:...|          N|       SOUTHERN|             C|               C|2023-01-16T15:25:...|         False|                  6|     []|
# |                       null|20349313|              Police|                 null| 230161186|2023-01-16T12:32:...|            903|        PASSING CALL|                 null|               903|           PASSING CALL|                    null|2023-01-16T12:32:...|2023-01-17T15:53:...|2023-01-17T15:56:...|2023-01-16T11:55:...|        HAN|2023-01-16T11:55:...|2023-01-16T11:55:...|           null|                null|                null|2023-01-16T11:55:...|          Y|           null|             C|               C|2023-01-16T11:55:...|          True|               null|     []|
# |                          1|20356621|              Police| Bayview Hunters P...| 230162952|2023-01-16T22:41:...|            909|      MEET W/CITIZEN|                 null|               909|         MEET W/CITIZEN|                    null|2023-01-16T22:41:...|2023-01-17T15:53:...|2023-01-17T15:56:...|2023-01-16T22:28:...|        HAN|2023-01-16T22:28:...|2023-01-16T22:28:...|       23541000|   03RD ST \ 25TH ST|{'type': 'Point',...|2023-01-16T22:28:...|          Y|        BAYVIEW|             C|               C|2023-01-16T22:28:...|         False|                 10|     []|
# |                         20|20355079|Municipal Transpo...|              Mission| 230162105|2023-01-16T20:11:...|            587| TRAF VIOLATION CITE|               22500F|               587|    TRAF VIOLATION CITE|                    null|                null|2023-01-17T15:53:...|2023-01-17T15:56:...|2023-01-16T20:11:...|       null|2023-01-16T20:11:...|2023-01-16T16:36:...|       23978000|24TH ST \ HARRISO...|{'type': 'Point',...|                null|          N|        MISSION|             C|               C|2023-01-16T16:36:...|         False|                  9|     []|
# |                         29|20346620|Municipal Transpo...|       Outer Richmond| 230160579|2023-01-16T08:11:...|            587| TRAF VIOLATION CITE|                 null|               587|    TRAF VIOLATION CITE|                    null|                null|2023-01-17T15:53:...|2023-01-17T15:56:...|2023-01-16T08:11:...|       null|2023-01-16T08:11:...|2023-01-16T08:09:...|       27534000|BALBOA ST \ 24TH AVE|{'type': 'Point',...|                null|          N|       RICHMOND|             C|               C|2023-01-16T08:09:...|         False|                  1|     []|
# |                         20|20351712|             Sheriff|              Mission| 230161879|2023-01-16T15:35:...|            913|      COMPLAINT UNKN|                 null|               913|         COMPLAINT UNKN|                    null|2023-01-16T15:35:...|2023-01-17T15:53:...|2023-01-17T15:56:...|2023-01-16T15:27:...|        HAN|2023-01-16T15:27:...|2023-01-16T15:27:...|       23964000|22ND ST \ POTRERO...|{'type': 'Point',...|2023-01-16T15:27:...|          Y|        MISSION|             B|               B|2023-01-16T15:27:...|         False|                 10|     []|
# |                          1|20356893|              Police| Bayview Hunters P...| 230163027|2023-01-16T23:28:...|            910|    WELL BEING CHECK|                 null|               910|       WELL BEING CHECK|                    null|2023-01-16T23:28:...|2023-01-17T15:53:...|2023-01-17T15:56:...|2023-01-16T23:21:...|        NOM|2023-01-16T23:21:...|2023-01-16T23:21:...|       34020000|  03RD ST \ KEITH ST|{'type': 'Point',...|2023-01-16T23:23:...|          N|        BAYVIEW|             A|               A|2023-01-16T23:19:...|         False|                 10|     []|
# |                         35|20357902|              Police|         Inner Sunset| 230162432|2023-01-17T02:45:...|           1030|WANTED VEHICLE / SUB|                 null|              1030|   WANTED VEHICLE / SUB|                    null|2023-01-17T02:45:...|2023-01-17T15:53:...|2023-01-17T15:56:...|2023-01-16T18:43:...|        REP|2023-01-16T18:43:...|2023-01-16T18:42:...|       27335000|19TH AVE \ NORIEG...|{'type': 'Point',...|2023-01-16T18:46:...|          N|        TARAVAL|             A|               A|2023-01-16T18:42:...|         False|                  7|     []|
# |                          3|20353799|              Police|       Haight Ashbury| 230162353|2023-01-16T18:15:...|            917|   SUSPICIOUS PERSON|                 null|               917|      SUSPICIOUS PERSON|                    null|2023-01-16T18:15:...|2023-01-17T15:53:...|2023-01-17T15:56:...|2023-01-16T18:08:...|        ADV|2023-01-16T18:08:...|2023-01-16T18:08:...|       26338000|ASHBURY ST \ HAIG...|{'type': 'Point',...|2023-01-16T18:08:...|          Y|           PARK|             C|               C|2023-01-16T18:08:...|         False|                  5|     []|
# |                         11|20345181|              Police|       Inner Richmond| 230160268|2023-01-16T03:59:...|            418|     FIGHT NO WEAPON|                 POSS|               418|        FIGHT NO WEAPON|                    POSS|2023-01-16T03:58:...|2023-01-17T15:53:...|2023-01-17T15:56:...|2023-01-16T03:48:...|        UTL|2023-01-16T03:48:...|2023-01-16T03:47:...|       27304000|GEARY BLVD \ 12TH...|{'type': 'Point',...|2023-01-16T03:55:...|          N|       RICHMOND|             B|               B|2023-01-16T03:43:...|         False|                  1|     []|
# +---------------------------+--------+--------------------+---------------------+----------+--------------------+---------------+--------------------+---------------------+------------------+-----------------------+------------------------+--------------------+--------------------+--------------------+--------------------+-----------+--------------------+--------------------+---------------+--------------------+--------------------+--------------------+-----------+---------------+--------------+----------------+--------------------+--------------+-------------------+-------+
# only showing top 20 rows

# %%
filtered_df = df.select("received_datetime", "intersection_id", "agency", "call_type_final_desc", "sensitive_call", "weather").filter(size("weather") > 0).filter("intersection_id is not null")

# %%
def max_weather(x):
    x = np.array(x)
    x_list = x.tolist()
    
    max = 0
    for elem in x_list:
        if float(elem[-1]) > max:
            max = float(elem[-1])
    return max
   
udf_max_weather = udf(max_weather, FloatType())

# %%
def convert_str_to_hour(x):
    timestamp = datetime.strptime(x, '%Y-%m-%dT%H:%M:%S.%f')
    return timestamp

udf_convert_str_to_hour = udf(convert_str_to_hour, TimestampType())

# %%
calls_weather = filtered_df.select(hour(udf_convert_str_to_hour("received_datetime")).alias("hour"),
                                   "intersection_id",
                                   "agency",
                                   "call_type_final_desc",
                                   "sensitive_call",
                                   udf_max_weather("weather").alias("max_precipitation"))

# %%
calls_weather.show(truncate=False)
# Out:
# +----+---------------+-------------------------------+--------------------+--------------+-----------------+
# |hour|intersection_id|agency                         |call_type_final_desc|sensitive_call|max_precipitation|
# +----+---------------+-------------------------------+--------------------+--------------+-----------------+
# |21  |23798000       |Police                         |WELL BEING CHECK    |False         |366.0            |
# |15  |23932000       |Police                         |FIGHT NO WEAPON     |False         |366.0            |
# |13  |27216000       |Police                         |WELL BEING CHECK    |False         |366.0            |
# |20  |20618000       |Police                         |RECOVER MISSING VEH |False         |366.0            |
# |11  |33288000       |Police                         |MISC                |False         |366.0            |
# |16  |24314000       |Police                         |SUSPICIOUS PERSON   |False         |366.0            |
# |10  |24557000       |Police                         |MISC                |False         |366.0            |
# |19  |20433000       |Police                         |COMPLAINT UNKN      |False         |366.0            |
# |18  |26693000       |Police                         |SUSPICIOUS PERSON   |False         |366.0            |
# |0   |24949000       |Police                         |SUSPICIOUS PERSON   |False         |366.0            |
# |8   |26653000       |Municipal Transportation Agency|TRAF VIOLATION TOW  |False         |366.0            |
# |9   |21516000       |Municipal Transportation Agency|TRAF VIOLATION CITE |False         |366.0            |
# |15  |34016000       |Police                         |PETTY THEFT         |False         |366.0            |
# |15  |20482000       |Police                         |WANTED VEHICLE / SUB|False         |366.0            |
# |14  |20754000       |Municipal Transportation Agency|TRAF VIOLATION CITE |False         |366.0            |
# |20  |23459000       |Police                         |FIGHT NO WEAPON     |False         |366.0            |
# |8   |24934000       |Police                         |FIGHT NO WEAPON     |False         |366.0            |
# |17  |30055000       |Police                         |ASSAULT / BATTERY   |False         |366.0            |
# |8   |34013000       |Police                         |BURGLARY            |False         |366.0            |
# |13  |27453000       |Police                         |WELL BEING CHECK    |False         |366.0            |
# +----+---------------+-------------------------------+--------------------+--------------+-----------------+
# only showing top 20 rows

# %%
hourly_count = calls_weather.groupBy("hour","max_precipitation","agency").count().cache()

# %%
hourly_count.show()
# Out:
# +----+-----------------+--------------------+-----+
# |hour|max_precipitation|              agency|count|
# +----+-----------------+--------------------+-----+
# |   1|            366.0|              Police|   18|
# |  16|             33.0|              Police|   43|
# |   7|            180.0|              Police|   35|
# |   9|            180.0|             Sheriff|    2|
# |  19|             89.0|              Police|   47|
# |  15|            366.0|             Sheriff|    1|
# |   6|            366.0|Municipal Transpo...|    3|
# |   5|            554.0|Municipal Transpo...|    1|
# |   9|             89.0|              Police|   31|
# |   5|            439.0|              Police|   20|
# |  18|             94.0|               Other|    1|
# |  13|             10.0|             Sheriff|    5|
# |   4|            180.0|              Police|    8|
# |   8|             91.0|             Sheriff|    5|
# |  12|             10.0|             Sheriff|    2|
# |  15|             10.0|             Sheriff|    3|
# |  17|             33.0|              Police|   53|
# |  17|             89.0|              Police|   49|
# |  15|             89.0|             Sheriff|    2|
# |   5|            366.0|              Police|   15|
# +----+-----------------+--------------------+-----+
# only showing top 20 rows

# %% [markdown]
# ###String Indexer for columns

# %%
def indexStringColumns(df, cols):
    # variable newdf will be updated several times
    newdf = df
    
    for c in cols:
        # For each given colum, fits StringIndexerModel.
        si = StringIndexer(inputCol=c, outputCol=c+"-num").setHandleInvalid("keep")
        sm = si.fit(newdf)
        
        # Creates a DataFame by putting the transformed values in the new colum with suffix "-num" 
        # and then drops the original columns.
        # and drop the "-num" suffix. 
        newdf = sm.transform(newdf).drop(c)
        newdf = newdf.withColumnRenamed(c+"-num", c)
    return newdf

# %%
categorical_cols = ["hour","agency"]
sti_df = indexStringColumns(hourly_count, categorical_cols)

# %% [markdown]
# ### One Hot Encode features

# %%
def oneHotEncodeColumns(df, cols):
    newdf = df
    for c in cols:
        # For each given colum, create OneHotEncoder. 
        # dropLast : Whether to drop the last category in the encoded vector (default: true)
        ohe = OneHotEncoder(inputCol=c, outputCol=c+"-onehot", dropLast=False)
        ohe_model = ohe.fit(newdf)
        #Creates a DataFame by putting the transformed values in the new colum with suffix "-onehot" 
        #and then drops the original columns.
        #and drop the "-onehot" suffix. 
        newdf = ohe_model.transform(newdf).drop(c)
        newdf = newdf.withColumnRenamed(c+"-onehot", c)
    return newdf

# %%
def removeColFromArray(cols, col):
    new_cols = cols.copy()
    if (col in cols):
        new_cols.remove(col)
    return new_cols

# %%
ohi_df = oneHotEncodeColumns(sti_df, categorical_cols)

# %%
ohi_df.show()
# Out:
# +-----------------+-----+---------------+-------------+
# |max_precipitation|count|           hour|       agency|
# +-----------------+-----+---------------+-------------+
# |            366.0|   18|(25,[15],[1.0])|(5,[0],[1.0])|
# |             33.0|   43|(25,[12],[1.0])|(5,[0],[1.0])|
# |            180.0|   35| (25,[8],[1.0])|(5,[0],[1.0])|
# |            180.0|    2| (25,[4],[1.0])|(5,[2],[1.0])|
# |             89.0|   47|(25,[17],[1.0])|(5,[0],[1.0])|
# |            678.0|   27| (25,[0],[1.0])|(5,[1],[1.0])|
# |            366.0|    1| (25,[7],[1.0])|(5,[2],[1.0])|
# |            366.0|    3| (25,[9],[1.0])|(5,[1],[1.0])|
# |            554.0|    1|(25,[14],[1.0])|(5,[1],[1.0])|
# |             89.0|   31| (25,[4],[1.0])|(5,[0],[1.0])|
# |            678.0|   17| (25,[2],[1.0])|(5,[1],[1.0])|
# |            439.0|   20|(25,[14],[1.0])|(5,[0],[1.0])|
# |             94.0|    1|(25,[16],[1.0])|(5,[3],[1.0])|
# |             10.0|    5| (25,[0],[1.0])|(5,[2],[1.0])|
# |            180.0|    8|(25,[23],[1.0])|(5,[0],[1.0])|
# |             91.0|    5| (25,[3],[1.0])|(5,[2],[1.0])|
# |             25.0|   17|(25,[16],[1.0])|(5,[1],[1.0])|
# |             10.0|    2| (25,[2],[1.0])|(5,[2],[1.0])|
# |             10.0|    3| (25,[7],[1.0])|(5,[2],[1.0])|
# |             33.0|   53|(25,[10],[1.0])|(5,[0],[1.0])|
# +-----------------+-----+---------------+-------------+
# only showing top 20 rows

# %% [markdown]
# ### Create a dataframe with features and label

# %%
va = VectorAssembler(outputCol="features", inputCols=["max_precipitation", "hour", "agency"])
va_df = va.transform(ohi_df).select("features", "count").withColumnRenamed("count", "label")

# %%
splits = va_df.randomSplit([0.8, 0.2])

# %%
train = splits[0].cache()
validation = splits[1].cache()

# %% [markdown]
# ## ML Goals (Diane Woodbridge)
# Develop a regression model to predict the number of crimes based on the time of the day, agency and precipitation.
#
# ## ML Outcome
# Was able to develop a model to predict the number of crimes/incidences using Random Forest Regressor and yield RMSE of 5.12.

# %% [markdown]
# ### Train model without/with cross validation

# %%
# witout CV
rf = RandomForestRegressor(maxDepth=10)
rfmodel = rf.fit(train)

# %%
# with CV

rf = RandomForestRegressor()
reval = RegressionEvaluator()
cv = CrossValidator().setEstimator(rf).setEvaluator(reval).setNumFolds(5)

#ParamGridBuilder() – combinations of parameters and their values.
paramGrid = ParamGridBuilder().addGrid(rf.maxDepth, [5, 10, 15, 20])\
                              .addGrid(rf.numTrees, [10, 20, 30]).build()

#setEstimatorParamMaps() takes ParamGridBuilder().
cv.setEstimatorParamMaps(paramGrid)
cvmodel = cv.fit(train)

# %% [markdown]
# ### Validate the model using validation set.

# %%
# without CV
validpredicts = rfmodel.transform(validation)
print(validpredicts.show())
reval = RegressionEvaluator()
print (reval.getMetricName() +":" + str(reval.evaluate(validpredicts)))
# Out:
# +--------------------+-----+------------------+
# |            features|label|        prediction|
# +--------------------+-----+------------------+
# |(31,[0,15,27],[55...|    1| 6.098390241956728|
# |(31,[0,15,26],[43...|   20|16.242162465670532|
# |(31,[0,17,29],[94...|    1| 4.621136858783918|
# |(31,[0,17,27],[25...|   17|15.805116198685345|
# |(31,[0,3,28],[10....|    2|2.7892117248613966|
# |(31,[0,15,26],[36...|   15|16.242162465670532|
# |(31,[0,22,26],[67...|   25| 18.53850510027879|
# |(31,[0,8,28],[25....|    1|1.8731791391520862|
# |(31,[0,15,27],[43...|    1| 6.098390241956728|
# |(31,[0,20,26],[25...|   30|33.780559011110164|
# |(31,[0,22,27],[55...|    2| 13.38651818791104|
# |(31,[0,2,26],[366...|   47| 36.66521133146994|
# |(31,[0,4,28],[300...|    1|2.0542422674868863|
# |(31,[0,5,28],[366...|    3|1.9047467830909202|
# |(31,[0,6,27],[300...|   22|23.317014747950637|
# |(31,[0,19,28],[67...|    1|1.1727899531024533|
# |(31,[0,12,27],[25...|    3| 3.299017943254684|
# |(31,[0,18,26],[43...|   34|33.898869687169494|
# |(31,[0,3,27],[300...|    7|14.891866276438876|
# |(31,[0,8,26],[33....|   37| 32.90856213996788|
# +--------------------+-----+------------------+
# only showing top 20 rows
#
# None
# rmse:5.43357125661537

# %%
# with CV
RegressionEvaluator().evaluate(cvmodel.bestModel.transform(validation))
# Out:
# Out[25]: 5.121427747912555

# %% [markdown]
# ### Store the feature and label dataframe to mongodb for future use

# %%
def sparseToDenseArray(sparse_array):
    return sparse_array.toArray().tolist()

udf_sparse_dense_array = udf(sparseToDenseArray, ArrayType(FloatType()))
va_df_dense_v_to_array =  va_df.select(udf_sparse_dense_array(va_df["features"]).alias("features"), va_df["label"])

# %%
va_df_dense_v_to_array.show()
# Out:
# +--------------------+-----+
# |            features|label|
# +--------------------+-----+
# |[366.0, 0.0, 0.0,...|   18|
# |[33.0, 0.0, 0.0, ...|   43|
# |[180.0, 0.0, 0.0,...|   35|
# |[180.0, 0.0, 0.0,...|    2|
# |[89.0, 0.0, 0.0, ...|   47|
# |[678.0, 1.0, 0.0,...|   27|
# |[366.0, 0.0, 0.0,...|    1|
# |[366.0, 0.0, 0.0,...|    3|
# |[554.0, 0.0, 0.0,...|    1|
# |[89.0, 0.0, 0.0, ...|   31|
# |[678.0, 0.0, 0.0,...|   17|
# |[439.0, 0.0, 0.0,...|   20|
# |[94.0, 0.0, 0.0, ...|    1|
# |[10.0, 1.0, 0.0, ...|    5|
# |[180.0, 0.0, 0.0,...|    8|
# |[91.0, 0.0, 0.0, ...|    5|
# |[25.0, 0.0, 0.0, ...|   17|
# |[10.0, 0.0, 0.0, ...|    2|
# |[10.0, 0.0, 0.0, ...|    3|
# |[33.0, 0.0, 0.0, ...|   53|
# +--------------------+-----+
# only showing top 20 rows

# %%
database = 'msds697'
collection = 'sf_record_feature'
user_name = 'admin'
password = 'msds697'
address = 'msds697.qgylt.mongodb.net'
connection_string = f"mongodb+srv://{user_name}:{password}@{address}/{database}.{collection}"

# %%
va_df_dense_v_to_array.write.format("com.mongodb.spark.sql.DefaultSource")\
                     .mode("overwrite")\
                     .option("uri", connection_string)\
                     .save()
